# %%
from bs4 import BeautifulSoup as bs
import re,csv, os, itertools, pandas as pd,docx2txt
from tqdm import tqdm
from pattern.web import PDF
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize
from spacy.lang.id import Indonesian
from html import unescape
from unidecode import unidecode
from bz2 import BZ2File as bz2
from textblob import TextBlob
import spacy

def LoadStopWords(lang):
    L = lang.lower().strip()
    if L == 'en' or L == 'english' or L == 'inggris':
        lemmatizer = WordNetLemmatizer()
        stops =  set([t.strip() for t in LoadDocuments(file = 'C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/stopwords_eng.txt')[0]])
    elif L == 'id' or L == 'indonesia' or L=='indonesian':
        lemmatizer = Indonesian() 
        stops = set([t.strip() for t in LoadDocuments(file = 'C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/stopwords_id.txt')[0]])
    else:
        print('Warning, language not recognized. Empty StopWords Given')
        stops = set(); lemmatizer = None
    return stops, lemmatizer

def fixTags(T):
    getHashtags = re.compile(r"#(\w+)")
    pisahtags = re.compile(r'[A-Z][^A-Z]*')
    t = T
    tagS = re.findall(getHashtags, T)
    for tag in tagS:
        proper_words = ' '.join(re.findall(pisahtags, tag))
        t = t.replace('#'+tag,proper_words)
    return t

def readBz2(file):
    with bz2(file, "r") as bzData:
        txt = []
        for line in bzData:
            try:
                txt.append(line.strip().decode('utf-8','replace'))
            except:
                pass
    return ' '.join(txt)

def LoadDocuments(dPath=None,types=None, file = None): # types = ['pdf','doc','docx','txt','bz2']
    Files, Docs = [], []
    if types:
        for tipe in types:
            Files += crawlFiles(dPath,tipe)
    if file:
        Files = [file]
    if not types and not file: # get all files regardless of their extensions
        Files += crawlFiles(dPath)
    for f in Files:
        if f[-3:].lower()=='pdf':
            try:
                Docs.append(PDF(f).string)
            except:
                print('error reading{0}'.format(f))
        elif f[-3:].lower()=='txt' or f[-3:].lower()=='dic':
            try:
                df=open(f,"r",encoding="utf-8", errors='replace')
                Docs.append(df.readlines());df.close()
            except:
                print('error reading{0}'.format(f))
        elif f[-3:].lower()=='bz2':
            try:
                Docs.append(readBz2(f))
            except:
                print('error reading{0}'.format(f))
        elif f[-4:].lower()=='docx':
            try:
                Docs.append(docx2txt.process(f))
            except:
                print('error reading{0}'.format(f))
        elif f[-3:].lower()=='csv':
            Docs.append(pd.read_csv(f))
        else:
            print('Unsupported format {0}'.format(f))
    if file:
        Docs = Docs[0]
    return Docs, Files

def DelPic(text): #untuk menghilangkan informasi gambar
    D = text.split()
    D = [d for d in D if 'pic.twitter.com' not in d]
    return ' ' .join(D)

def LoadSlang(DirSlang):
    Slangs =LoadDocuments(file = DirSlang)
    SlangDict={}
    for slang in Slangs[0]:
        try:
            key, value = slang.split(':')
            SlangDict[key.strip()] = value.strip()
        except:
            pass
    return SlangDict

#POS Tagging
from nltk.tag import CRFTagger
def postag(text):
    #Tokenisasi Data
    tokenized_sents = word_tokenize(text)
    #pemberian Tag tiap token
    ct = CRFTagger()
    ct.set_model_file('C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/CRFTagger-1.0/CRFTagger/model/model.txt') 
    #directorynya disesuaikan meletakan file crfnya, harus download dlu file crfnya
    pt = ct.tag(tokenized_sents)
    ptN = []
    noun = set(['NN','NNP', 'NNS','NNPS'])
    tmp = []
    for w in pt:
        if w[1] in noun:
            tmp.append(w[0])
    if len(tmp)>0:
        ptN.append(' '.join(tmp))
    return ' '.join(ptN)

def cleanText(T, fix={}, lang = 'id', lemma=None, stops = set(), symbols_remove = False, min_charLen = 0): 
    # lang & stopS only 2 options : 'en' atau 'id'
    # symbols ASCII atau alnum
    pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    t = re.sub(pattern,' ',T) #remove urls if any
    t = DelPic(t)
    t = unescape(t) # html entities fix
    t = fixTags(t) # fix abcDef
    t = t.lower().strip() # lowercase
    t = unidecode(t)
    t = ''.join(''.join(s)[:2] for _, s in itertools.groupby(t)) # remove repetition
    t = sent_tokenize(t) # sentence segmentation. String to list
    for i, K in enumerate(t):
        if symbols_remove:
            K = re.sub(r'[^.,a-zA-Z0-9 \n\.]',' ',K)
        
        cleanList = []
        if lang =='en':
            listKata = word_tokenize(K) # word tokenize
            for token in listKata:
                if token in fix.keys():
                    token = fix[token]
                if lemma:
                    token = lemma.lemmatize(token)
                if stops:
                    if len(token)>=min_charLen and token not in stops:
                        cleanList.append(token)
                else:
                    if len(token)>=min_charLen:
                        cleanList.append(token)
            t[i] = ' '.join(cleanList)
        else:
            if lemma:
                K = lemma(K)
                listKata = [token.text for token in K]
            else:
                listKata = TextBlob(K).words
                
            for token in listKata:
                if token in fix.keys():
                    token = fix[token]
                
                if lemma:
                    token = lemma(token)[0].lemma_
                if stops:    
                    if len(token)>=min_charLen and token not in stops:
                        cleanList.append(token)
                else:
                    if len(token)>=min_charLen:
                        cleanList.append(token)
            t[i] = ' '.join(cleanList)
    return ' '.join(t)

# %%
data = pd.read_csv('C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/review_tokped.csv')
listReview=data['Review']

# %%
#Tanpa POS Tag
import pickle
from tqdm import tqdm_notebook as tqdm
import nltk
from nltk import word_tokenize

Slangs=LoadSlang( 'C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/slang.txt')
listRev = [d for d in data['Review']]

stops, lemmatizer = LoadStopWords(lang='en')
for i,d in tqdm(enumerate(listRev)):
    try:
        #i=i.translate(to='en')
        #i= nltk.word_tokenize(i)
        listRev[i] = cleanText(d,Slangs, lemma=lemmatizer,lang='en', stops = stops, symbols_remove = True, min_charLen =3)
    except:
        print(i)
#print("done!!! {0} review".format(i+1))
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
stops, lemmatizer = LoadStopWords(lang='en')
for i,d in tqdm(enumerate(listRev)):
    try:
        #i=i.translate(to='en')
        #i= nltk.word_tokenize(i)
        listRev[i] = cleanText(d,fix={}, lemma=lemmatizer,lang='en', stops = stops, symbols_remove = True, min_charLen =3)
    except:
        print(i)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
listRev
# Out:
# ['recommended',
#  'relied cheap mundane item pricy gadget extra care handling shipping delivered expected satisfied choice store courier user friendly design comprehensive',
#  'ovo shovel treatment dissapointed narrow money expect happy use point platform awful asinine use cashback turn cannae ongoing payment purchase item put..full',
#  'feature failed much like chat feature crashed wouldn load improvement couldn load chat experience time month uninstall install still..full',
#  'good functioned well minimum crash',
#  'fly brother great work proudness heart',
#  'favourite update waiting long enjoy online',
#  'simple market place great job workin',
#  'instant delivery not adjustment easier understand',
#  'stupid order like month order package',
#  'wonderful indonesia',
#  'good',
#  'best',
#  'nice uninstall change tokocash ovo',
#  'apps stable secure online transaction',
#  'good useful',
#  'great complete feature product',
#  'good aplication..easy use',
#  'server error annoying good',
#  'mantaplah tampilan simple clean like',
#  'trusted platform high security transaction buyer seller',
#  'nice simple buying selling good',
#  'great trading connect achieve big',
#  'good highly recommend',
#  'helpful online store promos',
#  'nice online shop simple payment method',
#  'good help',
#  'hope pay order tcash telk msel',
#  'love',
#  'improvement seaching feature include word searching machine',
#  'happy cashback tracking order useful everytime ordered great apps',
#  'not use coupon term condition',
#  'trusty online shop ..i shop',
#  'good paying',
#  'best indonesian commerce',
#  'great apps..very helpfully life easy',
#  'good response fast delivery product good quality',
#  'trusted recommended good',
#  'good buy',
#  'helpful secure trusted good service priority choice online good work',
#  'purchase buy double payment not check get double charge time transaction dont center customer service give explain chat response month not compli..full',
#  'online not buy thing online pay tax buy voucher game',
#  'like product varian price brand option buy',
#  'favorite store point buyer seller promo pay internet service monthly.. help',
#  'easy use range product market place problem fraud detection',
#  'today buying provisi not location not address not picking telephone email telephone contact',
#  'useful user friendly easy navigate nice gui well organized..',
#  'solution gampang pakai nya gak neko neko.. best',
#  'best apps online trading indonesia variety buyer seller',
#  'easy use buy thing idea buy love',
#  'start buyer sell second comic book perfect condition bebe book',
#  'great apps sell buy safety kind transaction voucher promo easy use',
#  'great selling buying special apps seller helpful',
#  'simple fast easy use clean interface love filter menu',
#  'easy buy sell..i love much',
#  'great choice great reward',
#  'online shop nice apps easy use',
#  'like better',
#  'confidence buying thing resolution center customer minded',
#  'easy use secure helpful online',
#  'stop easy access payment method option',
#  'good best recommended',
#  'great place sell buy online..',
#  'good..but extra promo free delivery',
#  'secure friendly user seller fast response recommended',
#  'easy use payment method helpful',
#  'great place shop promo',
#  'best online shop indonesia',
#  'good apps avoid change menu',
#  'great apps easy use',
#  'good online market place recommended',
#  'good easy recommend',
#  'helpful safe easy use love',
#  'promotion cash',
#  'good apps',
#  '',
#  'someday achieve like amazon',
#  'good market place star',
#  'nice shopping..i',
#  'good helping fast',
#  'best online shop indonesia',
#  'love',
#  'helpful frequent discount sale..',
#  'easier use reward',
#  'best commerce indonesia',
#  'best online mall good work',
#  'bring level service excellent',
#  'tokocash replaced ovo point reksadana easily',
#  'nice apps..easy use beware addicted',
#  'friendly use easy online shop',
#  'great easy used.i loved tokopedia.because user friendly',
#  'supportful love',
#  'currently best market place indonesia',
#  'nice complicated use',
#  'easy search shop good apps',
#  'helped slot searching good',
#  'best online apps',
#  'good',
#  'nice place easy',
#  'simple praktis fast..',
#  'nice complete easy use',
#  'best online',
#  'cool market place lovely',
#  'vote abd thumb',
#  'crashed blue happened like tenth time coupon expensive',
#  'great recommended haven installed missed love cashbacks',
#  'choice good price good service easy use',
#  'best trusted personal commerce indonesia',
#  'help time shopping..',
#  'button single thing life',
#  'easy use transaction well',
#  'search product good good apps',
#  'good online easy use',
#  'experience good tks',
#  'useful me.. helpful',
#  'good solution online',
#  'simple easy use money',
#  'recommended indonesia commerce',
#  'great great merchant easy compare price',
#  'help much daily life.make easier simple',
#  'good payment not easy',
#  'thing good thing mean..',
#  'helpful addictive easy use great',
#  'awesome.. user friendly..',
#  'satisfy order thing',
#  'good apps helpful',
#  'easy access product suggestion history previous order',
#  'anrs view change phone unusable issue competitor apps',
#  'love integrated apps making user friendly life easier',
#  'best online shop indonesia easy use variety good',
#  'awesome online easy use user friendly give benefit',
#  'guess time transaction delivery time accurate pay bull delivery',
#  'best online market fast good response comfortable safe shop',
#  'love give free shipment facility spent buy product 100 bought product charged shipment fee',
#  'useful friendly user good trusted seller here.. recommended..',
#  'easy use item certified original item',
#  'helpful finding thing specific',
#  'easy cheap convenient',
#  'great great interface online',
#  'simple user friendly',
#  'search function slow seller not active terminate item minimize time search thing picture item dark reviewed proor uploading',
#  'bad tracking order customer difficult use slow process',
#  'supplier not respond customer complaint',
#  'ability change language',
#  'pray good',
#  'great trusted transaction.. useful refreshing',
#  'good application.. recommend',
#  'activation ovo sad',
#  'smart smart',
#  'helpful get stuff',
#  'update cant search product crash dev issue like older version',
#  'great hard get solving issue',
#  'loved simple use',
#  'recommend online store thankyou',
#  'good online',
#  'love',
#  'reason shipping option isn address version work fine know.. inconvenient buy hope',
#  'improvement bought plane ticket time not get get declined file complain problem answer not helping fut..full',
#  'liked single event payment method changed ovo online payment disappointed use',
#  'good apps bought note shipment lost time jne hope protect buyer seller',
#  'efficient improvement payment confirmation',
#  'helpful buy tracking shipping easy payment',
#  'not good usual tokocash change ovo thing',
#  'great helper official store like',
#  'helpful useful easy use.. discount.. hahhaha',
#  'helpful apps good service good deal like',
#  'quick response complete reliable',
#  'easy use price competitive',
#  'good service helpful',
#  'good slow response much adsense',
#  'great online',
#  'best commerce indonesia',
#  'update not login connection open google play fine',
#  'easy product',
#  'me..very friendly useful',
#  'good help stuff need..',
#  'good recommended use buying',
#  'complete comprehensive info good seller',
#  'good market place buying selling',
#  'complicated not user friendly apps',
#  'pretty satisfying cashback promotion work matter second update account additional balance',
#  'program starting mess picture awfull slow changing time loser stop',
#  'help choose kurir canceled order money suck',
#  'perfect buying thing download good trust',
#  'help transaction buying selling securely',
#  'great though..its favourite online shop..its fast safe trust..thx',
#  'update apps open picture price phone.. come..',
#  'update problem solved installing',
#  'updated picture viewed screen',
#  'good good work..',
#  'useful',
#  'stuck phone heavy apps',
#  'good easy navigate',
#  'good interface easy use',
#  'best online store indonesia',
#  'amazing experience online',
#  'best online store',
#  'simple helpful',
#  'good online shop choose want..then click..click..click..and wait delivered',
#  'good complete download invoice claim unfortunatelly admin fee not appear invoice',
#  'nice help hope future feature improvement',
#  'good won load image mobile data',
#  'good feel safe payment verified bank',
#  'useful online purchase daily',
#  'help search item needed competitive price',
#  'useful secure buy',
#  'good excellent improved.. nice',
#  'reliable online apps',
#  'day gold member currently safest making online transaction money remained confirmed item received problem',
#  'help mall save time',
#  'running ignore humanity seller',
#  'good need..helps',
#  'great',
#  'easier thing tht buy',
#  'best online store indonesia',
#  'nice apps',
#  'nice indonesian market complete fast',
#  'best online',
#  'great helping',
#  'use online pay benefit love cashback flashdeal realtime',
#  'best online great cancel refund money automatically seller exceeds processing time',
#  'favourite online shop comfortable easy use good job',
#  'nice seller buyer famous market place indonesia',
#  'buy site benefit',
#  'good buying selling',
#  'good easy use',
#  'currently best online apps',
#  'best online',
#  'indonesia best commerce site',
#  'good apps hope better message handling transaction buy sell',
#  'like size product not clear length width thighness..',
#  'best market place',
#  'nice love transaction',
#  'useful fast action..',
#  'time transaction recommended',
#  'best market place apps loyal user buy sort stuff knick knack like cute necklace honda not joking',
#  'fav market place dear team mind reputation not ninja express partner check ninja',
#  'add free delivery digital product seller selling digital product like steam wallet itunes gift card google play gift card battlenet gift card ridiculous seller send package delivery service.. bug..full',
#  'imagine live nowadays lifestyle',
#  'private chatting soo confused time installed',
#  'easy use buying selling breeze love',
#  'get item description cheaper price',
#  'good help cant mobile shop stuff',
#  'good online shop platform discount cashback tempting',
#  'good useful visit store..',
#  'good apps finding thing life',
#  'nice apps help local product grow reach customer',
#  'helpful loading time instagram',
#  'love user interface.. clear simple',
#  'life easier mine..',
#  'best national online used..',
#  'amazing search thing easy',
#  'great great gift card great benefit',
#  'great simple interactive',
#  'easy helpful wan store buy easy original product free ongkir cashback help customer online store price cheap..full',
#  'helpful place choice model price',
#  'ovo dont like it..move red black pink',
#  'update slowly open task filter dark screen wait second',
#  'best buy need..good seller good products..',
#  'besst recommended shoping..to mee',
#  'good helpful',
#  'satisfied',
#  'brilliant useful',
#  'good work improving better',
#  'like good service',
#  'best commerce loved',
#  'easy voucher free courier charge',
#  'friendly user buyer competitive',
#  'easy use communicative display',
#  'loved it..good job team',
#  'helpful good service',
#  'user friendly local online apps promotion cover daily good offer',
#  'unusable not responding long time access menu',
#  'best online indonesia easy use trusted good service',
#  'excellent daily basis online sadly event customer',
#  'best online store indonesia helpful',
#  'best online store indonesia',
#  'verified responded processed arrived good job like',
#  'english version',
#  'hustle relax good arrived',
#  'best online shop universe',
#  'crash upgrade server',
#  'good searching',
#  'good sale shop easy',
#  'bought train ticket choose seat payment seat changed reason not help customer service bad not get cash not recommended',
#  'cancellation button not wait hour wait hour wait seller response buyer like lazy seller hour max seller not respond buyer cancel seller reliable change syst..full',
#  'favourite commerce cashback handy collaboration ovo highly recommended',
#  'semakin user friendly nya clean sleek good work',
#  'buyer perfect online shop recommended',
#  'trustworthy online marketplace',
#  'finger here..',
#  'easy love',
#  'great online',
#  'good apps living indonesia',
#  'bring sort sold item useful feature',
#  'complain good feedback.. give customer makesure product receive not.. customer satisfy',
#  'helpful anywhere.just stay good',
#  'buyer complaining fake reject item seller not effective much time seller use fake photo hiperbolic description missguide buyer buy good',
#  'good helping search good shop cheaper',
#  'user friendly easy transparency..',
#  'upgrade nothing happened order fail',
#  'great apps transaction easier get benefit promos',
#  'you.. bryan adam',
#  'best price comparison..',
#  'good online market love',
#  'easy use easy thing good apps',
#  'function..',
#  'great helpful good thing before.. precaution shop addicted..',
#  'price good fashion product online fashion time time shd change avoid customer bored give variation good luck',
#  'remove kok cuman diliatin aja notification everytime checked product annoying',
#  'nice apps spot helpful searching bravo',
#  'confusing comment live chat',
#  'favourite online merchant service',
#  'easy use helpful best',
#  'verry helping buy worried',
#  'doubt best choice 2018',
#  'helpful love',
#  'responsive user expectation',
#  'far..no complaining..',
#  'help',
#  'simple',
#  'easy use online',
#  'good apps seek stuff secure payment',
#  'fitures not working like chat robot solve problem',
#  'force close check note',
#  'worthy called asian unicorn',
#  'helpful easy use good job',
#  'useful apps offering option buy product',
#  'online shopper',
#  'great apps touch development',
#  'convenience easy access secure',
#  'personally favourite online place kind item promos discount cashback allows discover stuff not buy easily physically',
#  'good chat purchase smooth unnecessary change update example like long doe start',
#  'update feature sort listing buy not feature help',
#  'cancel stock refunded refund not dont',
#  'beware competitor interface not character payment verification not fast competitor couple minute waiting thx',
#  'favourite online shop..its easy use easy pay save..thank',
#  'hate remove sort penjualan bring',
#  'best like previous style left slide message wishlist',
#  'favorite online shop easy use much feature',
#  'nice track delivery..thanks satisfied service',
#  'restaurant star michelin',
#  'good system..',
#  'quality service',
#  'good improve menu',
#  'best online use online apps trusted secure easy use good service',
#  'payment love much',
#  'useful recommended',
#  'good running well nice',
#  'place search',
#  'apps better',
#  'best market place integration ovo cashback',
#  'cool apps friendly user love',
#  'time everytime tap product suddenly closed xiaomi note pro',
#  'recommended trusted online shopping..a fantastic coupon awesome services..the best online',
#  'best market place indonesia..',
#  'easy use understand',
#  'today easiest payment apps',
#  'useful nice dude',
#  'ok. complain',
#  'good packing easy use..',
#  'best online store indonesia',
#  'simple easier stuff money',
#  'filter choice like price range seller city location much easier photo seller change photo real picture only..',
#  'not pay credit card wasting time money.. give star app..',
#  'great love notification like personal assistant great job',
#  'satisfactory place spare plastic screw shoe rack',
#  'best apps market place connected buyer seller like boundary',
#  'best online shop indonesia safely transaction user friendly',
#  'buy place',
#  'good helpful promotion use pay',
#  'easy promos coupon number magic egg well',
#  'easy use useful online trading',
#  'better better adv credit card charge consider update free charge',
#  'love cashback promotion',
#  'user friendly helpful',
#  'best like use',
#  'best',
#  'trusted seller quality product product description prompt response recommended',
#  'error logged account internet connection error',
#  'bad customer service uninstalled',
#  'simple easy use plenty loyalty programs..',
#  'time good',
#  'best online shop indonesia',
#  'best online',
#  'user interface great feature',
#  'easy use informative..',
#  'send notification',
#  'good apps life easier',
#  'best online store',
#  'improvement perfect',
#  'update risk frequent user fraction useful capability sort thing sale performance decide remove feature blue slip finger golden rule repair isn..full',
#  'good installed google account indonesia expat working jakarta google account created rectify asap created account',
#  'improve filtering feature allowing user enter product specification sification instance search handphone nfc support storage 32gb.. toko pedia..',
#  'nice good work buy stuff well',
#  'advice remove stuff stock not screen',
#  'not interactive lacked professionalism customer support',
#  'good error whatsoever great job',
#  'helpful cashback',
#  'easy use simple menu navigate',
#  'super kind online financial transaction',
#  'useful apps easy use',
#  'best online platform indonesia',
#  'easy use customer service cooperative helpful',
#  'good experience daily transaction',
#  'recieved thing good condition fast reasonable price',
#  'prefer good',
#  'best online shop ever.. responsible attractive consumers..',
#  'reliable not bug issue user friendly indonesian',
#  'plz add ship ticket not flight ticket.. use ship travel island indonesia.. like pelni private ship seas..',
#  'best satisfy costumer successful',
#  'good best online experience',
#  'best commerce indonesia',
#  'love altought rendered well tablet',
#  'good..i like much..',
#  'user friendly interface',
#  'good hope best',
#  'user friendly product quality good money',
#  'favorite shop online',
#  'help much buy touch',
#  'best market place',
#  'fast response nice product..',
#  'change english option not user friendly sends round round circle',
#  'good like buy everywhere..',
#  'love item buy',
#  'complete online service hand',
#  'good apps convenient get',
#  'best online market place offer',
#  'satisfied tokopedia..',
#  'helpfull.. best online shop indonesia',
#  'choose online',
#  'help cheaper price..haha',
#  'unclear change language english obvious',
#  'good easy understand recommended',
#  'easy use easy transaction',
#  'love hope someday',
#  'easy use',
#  'promos recommended apps urban life',
#  'good easy use',
#  'buy easy use',
#  'easy access fast cash good job',
#  'apps help buy urgent time',
#  'easy use user friendly nice',
#  'good simple choice',
#  'page slow wishlist management i.e deleting product wishlist loading better save change leaving wishlist page wishlist page hassle',
#  'perfect better get government partnership shipping overseas help merchant sell product countries..',
#  'good glitch samsung rotate screen playstore turn auto rotate pempelian tab crash good making apps sell online hard use daily nice day',
#  'good apps experience simple easier',
#  'best commerce market opinion thing',
#  'user friendly apps best start',
#  'amazing commerce indonesian product recommended',
#  'good promos program not good shopee',
#  'good use coupon write',
#  'service helpful progress cheer',
#  'great helpful seller customer improved rating procedure doesn benefit customer',
#  'great apps buy store choose',
#  'easy settle payment cashback benefit transaction',
#  'good place online shop easy navigation',
#  'easy use product',
#  'good commerce offer promotion',
#  'useful apps secure',
#  'place get needs..',
#  'use commerce 2016',
#  'updated version flight menu cant work chose destination hit search button not work asap',
#  'soo user friendly.. complicated refund.. protected buyer prompt complain procedure',
#  'easy use vendor good category good fast product searching filtering',
#  'improvement heavier sorting item sale',
#  'best commerce indonesia easy use..',
#  'useful',
#  'user friendly complete feature',
#  'online status like online',
#  'good improve',
#  'helpful reasonable price',
#  'good market place problem issue complains not good admin not helpful email talk experience reply robotic scripted not recommended',
#  'stuff save time money travelling stuff saving trip',
#  'like easy fast secure transaction',
#  'add bought item checkout not nominal pay',
#  'user friendly.. ovo easier payment..',
#  'bug notification not disappeared opened',
#  'user friendly option recommend seller',
#  'cool application.. easy used.. trusted application..',
#  'choice',
#  'user friendly easy thing buy easy claim promo including pln pdam telkom recommended online',
#  'bad customer support customer service problem complain specific problem body answer call..',
#  'friendly interface easy use navigate paying',
#  'nice fast service easy use',
#  'great help market product buy stuff',
#  'user friendly great experience bought book',
#  'best commerce easy link link',
#  'clear transact apps much',
#  'easy buy good thing cheaper',
#  'promotion cashback store',
#  'user friendly reliable',
#  'good apps cheaper price olshop..',
#  'best local market place',
#  'nice get cashback',
#  'option good include local store interface easy use accurate real time delivery tracking',
#  'useful online apps note shipping discount free ongkir..',
#  'good easy use airline airline ticketing menu airline ticket price higher promotion code',
#  'apps not provide good fast solution dispute give improve',
#  'access tab not use coupon column coupun code unable click',
#  'good..trusted online shopping..easy use..helpful',
#  'good easy use.. good job toped.. going',
#  'easy fast exactly',
#  'convenience reliance trustworthy',
#  'helpful apps fast response clear',
#  'good love promo voucher',
#  'good apps easy use secure transaction program product',
#  'easy use promotion useful seller buyer',
#  'convenient ease transaction daily great work',
#  'helpful love transaction',
#  'love much..online wonderful',
#  'interface good promo fewer',
#  'helpfull..very good..keep success',
#  'help awesome easy use trustworthy innovation',
#  'good favorite online shop recommended',
#  'amazing nice responsive online shop',
#  'problem good job lur',
#  'helpful rare time wasting going town shop thing click',
#  'great olshop promote local healthy farmer product butterfly pea bunga telang',
#  'love',
#  'thing chill',
#  'good application..good online experience',
#  'good useful best',
#  'huge fan early 2017 strong advocate bought electronics supply rarely problem replaced tokocash ovo stopped use ovo reverted to..full',
#  'fact good ecom market buy product cheap price good quality good cashback not entered tokocash entered ovo point reuse redeem ovo point place have..full',
#  'hang lag scrolling clicking smooth lag multitasking clear hassle free problem customer support help best market place indonesia excellent',
#  'apps now..great experience..with ease use..good promo..and star seller..but room greater improvement tough..keep up..',
#  'use pay realy helpful easy promos discount great save money',
#  'violet blue poem suck doesn rhyme agree guy best',
#  'friendly buyer seller great thx',
#  'understandable practical commerce',
#  'great add time 23.00 payment method transfer internet banking',
#  'good place thing faster',
#  'easy use great commerce apps',
#  'easy use helpful',
#  'best online',
#  '2016 love work lightweight informative hassle click page latest update thing worse add extra second seller display collection etalase',
#  'not convenience store',
#  'nice apps.. reall easy use user friendly competitive price..',
#  'buy better much pay include fee messing fee',
#  'user friendly help',
#  'great apps help much',
#  'highly recommended online',
#  'useful anytime love it.. discount voucher.. better additional comment menu gofood..',
#  'great user interface feature great job tokopedia.. great work',
#  'good online shop indonesia nice performance good service customer',
#  'good easier online',
#  'satisfied services..',
#  'havent experience',
#  'favorite online shop',
#  'stable user friendly',
#  'easy use quick process good notification reliable rating helpful assist commerce online best compared competitor',
#  'easy use apps display nice information.. seller recommended.. worry shop site give warranty return money problem seller',
#  'like difficulty sign change password couldnt order thing help buy stuff',
#  'time get cashback lucky egg result error useless lucky egg',
#  'best recommend',
#  'helpful best',
#  'user friendly comfortable app..',
#  'helpful online',
#  'good simply promotion',
#  'frustated single time browsing i.e search result accidentally tilt device display mode change small grid tile big grid change small grid scrolling reset scroll again.. sorry..full',
#  'online shop bad experience vendor',
#  'best commerce hope discard kok cuma diliatin aja bla bla bla.. push notification',
#  'good helpful basically',
#  'best store indonesia great customer service',
#  'easy use offer discount gift..',
#  'awesome.. unicorn startup indonesia.. simple shopping..',
#  'fantastic point view',
#  'best online store trust',
#  'good apps love',
#  'description experience placeholder',
#  'best product best dilivery',
#  'service wise good good human subjective mind rated lower simply website advertisement open play store blin hate cyka blyat',
#  'stop platform nice like',
#  'best online',
#  'great app.. easy use shop',
#  'good service support ukm',
#  'good.. tokped..',
#  'advance improving massage customer',
#  'easier use version',
#  'easy use lower price apps safe transaction',
#  'simple easy use importantly working seamlessly',
#  'helpful secure sell',
#  'love useful',
#  'dont problem good',
#  'happy helpful',
#  'good easy use monitorize order progress',
#  'best',
#  'lazy person',
#  'cheap indonesian development hard thing account not translated speak bahasa indonesia',
#  'nice user interface great feature easy access ovo digital money hoping work well',
#  'best market place apps indonesia free shipping hehe',
#  'like shop shop favorite cellphone..just u..toped',
#  'best apps online indonesia..',
#  'amazing shop online',
#  'favourite place searching buying product',
#  'good buyer seller',
#  'good helpful..useful',
#  'helpful thing imagine good price',
#  'wonderful online store far.. cash',
#  'improved get lost..',
#  'bermanfaat sekali.. life simple thx',
#  'error.. updated..',
#  'inbox account not opened update',
#  'best market place indonesia',
#  'error update not check notification user page',
#  'good apps easy use',
#  'friendly user helpful excellent',
#  'apps oftenly error not open account menu sign sign work sign get token input verify number',
#  'mobile apps error message inbox notification',
#  'favourite online shop indonesia',
#  'good market place biggest indonesia familiar',
#  'good service help get',
#  'inbox account..',
#  'best online market place..',
#  'best online shop indonesia..',
#  'easy use good security browsing item sorted price confusing mixed promoted item middle desktop version',
#  'wan best online',
#  'helpful easy use method payment responsive helpful',
#  'better easy sell something..keep going toped..',
#  'simply best commerce indonesia',
#  'easy use beneficial online',
#  'minor bug auto update checkout',
#  'good oftenly change absurd confusing',
#  'amazing online store..i easy buy thing',
#  'good..keep',
#  'good experience ovo integration much convenient',
#  'easier thing good price',
#  'maintain merchant sell original not recondition product',
#  'disappointed seller',
#  'time user not much',
#  'good market place..and nice',
#  'easy daily good price reasonable easy use user friendly',
#  'best online better apps similar.. cheaper discount give best experience',
#  'good experience improvement achieved stricter filtering seller better buyer protection',
#  'cheapest all.. trust',
#  'good',
#  'frendly use like choice',
#  'give star hard upload thing developed easy use good job',
#  'best indonesian commerce best best best server best feature',
#  'advertisement spammer browser.. omg remove uncomfortable.. seriously blocked pop advertisement download apps disgusting bad grammar',
#  'avoid apps lousy customer service',
#  'easy use user friendly good design',
#  'love good price good',
#  'great apps help easier anything..',
#  'easy use helpful',
#  'suddenly bugging installed uninstalled repeatedly not solved help update version worst update update update better interface',
#  'item here.. secure payment guaranted..',
#  'good customer',
#  'good platform buying good service',
#  'online shop great indonesia',
#  'impeccable service trustworthy',
#  'helping everyday..',
#  'helpful good',
#  'satisfied alibaba investment attractive free discounted ongkir deal fewer restrictive ovo cash point not flexible generous structure play silly pecah telor',
#  'best online shop trusted easy.. improvement nothing perfect',
#  'best market place shank',
#  'simple reliable safe',
#  'user friendly baby boomer generation',
#  'good easy use easy transaction haven get problem apps',
#  'useful online application.. safe buy buyer sell seller',
#  'stable start feature optional prodcut buy',
#  'helping lazy situation',
#  'helpful apps somethin bought friendly interface',
#  'user friendly commerce great apps',
#  'easy trusted seller nice',
#  'judge aparrently good get market place fake seller day duped seller changed account stole money didn phone number searched everywhere.i number not',
#  'well favorite buy get confused gui category',
#  'best',
#  'best application..user friendly easy use',
#  'received defect product shop replace whatsapp replacement good',
#  'user friendly useful easily search item compare best price',
#  'loved better great',
#  'good apps error good job',
#  'good.. expectation good work guys..',
#  'easy use variaties safe money transaction',
#  'time thing',
#  'great app.. easy use star rating.. awesome',
#  'work great easy used.. stars..',
#  'favourite market place easy seller buyer',
#  'good recommended',
#  'good buy',
#  'shop trust buy thing',
#  'easy easy time saving',
#  'apps changed life feel like assistant help best price amongs acquire click',
#  'best online market place easy great choice havent disappointed commerce',
#  'excellent.. earn customer service responsive resolving issues.. response slow text book',
#  'great apps buyer seller good work',
#  'helpful apps purchase thing',
#  'perfect good job',
#  'update confuse me..',
#  'best seller going',
#  'install latest update',
#  'updated time account not get cashback buying process address wife email handphone number bank account complained responded promotion team ktp',
#  'helpfull.. here..',
#  'easy use.. life easier',
#  'great app.. simple user friendly',
#  'easy use helping transaction',
#  'buyer give complete product seller price courier delivery product perfect helpful',
#  'ok..very helpful..and easy operate..good price choice product sold..',
#  'good live tracking delivery',
#  'best online 2013',
#  'secure commerce site moment buyer seller problem hopefully continue good',
#  'ovo thing hate mandatory update cant not selling data',
#  'good good seller buyer',
#  'satisfied life easier',
#  'good ebay',
#  'easy use nice experience',
#  'helpful',
#  'handy useful',
#  'indonesia love apps',
#  'happy shop delivery super fast city competitor longer city suggestion carefully select seller info originality merchandise',
#  'problem purchase best online appearance not complicated like good work team',
#  'apps love apps update better good work',
#  'good best opinion',
#  '2019 doesn support split screen',
#  'good discount',
#  'ceo great serving',
#  'finding daily simply fast',
#  'best retailer indonesia',
#  'good online market better service coupon get cashback product choice',
#  'love buy',
#  'easy simple process effective',
#  'useful developing',
#  'great paying monthly lacking delivery discount long distance buyer like tragic existence commerce give free delivery nothing',
#  'fast reliable online happy use',
#  'help much simple easy',
#  'great apps daily use daily',
#  'easy learn easy pay easy shop',
#  'bad cashback not received properly seemingly proper user fake user missleading rule bad dissapointment apps',
#  'useful good easy use provided payment ovo cash ovo point',
#  'deposit hard get money',
#  'love much feature easy use..',
#  'good anythink trusted',
#  'easy use good service',
#  'instant online shop throught mobile',
#  'free shipping 1courier rules..',
#  'easy use user friendly',
#  'good useful user friendly',
#  'best unicorn indonesia',
#  'x.. ketik deal.or not xmxmdxnpsnz',
#  'good handicap complain',
#  'great payment option',
#  'language preference not english language option understand bahasha..',
#  'useful easy use best user interface love like',
#  'good service',
#  'good purchase helpful..',
#  'not change language not help',
#  'daily ovo user partnership smile big',
#  'easy use useful feature',
#  'easy access.. great apps',
#  'help nice',
#  'helpful safe payment method',
#  'good apps.. quick reply response',
#  'efficient online dont time item sport equipment video game license key problem price delivery expensive day ove..full',
#  'help cheap classy thing purchase help customer service responsive complaint confirm trader purchasing prevent get tricked bad',
#  'useful easy navigate best',
#  'best olshop get tired order promo kind service',
#  'good buy cheapest price good',
#  'good online like',
#  'like apps time.. good..',
#  'help lot.. you..',
#  'nice app..easy guide rarely crash..',
#  'user friendly promo',
#  'app.. love it..',
#  'easy use choice',
#  'good apps integrated ovo payment easy',
#  'great user experience stop changing interface hotlolist tab recomm',
#  'apps great',
#  'nice love shop',
#  'best buyer seller',
#  'easier buy product store going store place nice',
#  'improvement perfect improve',
#  'good thing cant load image product',
#  'helpful apps good price good quality good',
#  'good seller buyer recommended',
#  'prefer market place apps',
#  'help things.. suka bikin rempong',
#  'fast easy operate',
#  'user friendly use time problem arised',
#  'best online shop indonesia',
#  'useful user friendly',
#  'give dark mode eye comfortablely',
#  'easy use benefit',
#  'worst online product shop shoppee better wont verify cant pre purchase ticket jakarta toy comic fair 2019 hopefully bankrupt piece garage waste time screw going ticket booth',
#  'love easy pay creadit card good needed promotion special moment',
#  'easy use payment option stop online',
#  'user friendly fast date.. easy refund well',
#  'helpful thx team create',
#  'like better simple wan shop xixixi',
#  'great online shopping..',
#  'forever disappointed like hacking account didn responsible thought otp code nonsense latest version logging account usi..full',
#  'feature updated nicely version list infected advertisement list unwished list point buyer convenience star advertisement wisely',
#  'happy tokopedia.. good quality good product.. muuch',
#  'good good automotive electricity',
#  'easy use commerce favorite',
#  'simple easy use mudah dimengerti',
#  'love apps user friendly',
#  'star electric much discount',
#  'suddenly crashing profile unable load kindly check',
#  'better competitor a.k.a',
#  'best online indonesia',
#  'get benefit daily solution',
#  'user choice today error upsetting log password wrong change password time email account log s..full',
#  'installed hoping helpful opening browser time buy nope doesn function well time sign couldn get otp phone time trial chose sign option an..full',
#  'flash sale scam get flash sale suddenly kicked account cant log waiting 1hour minute long time today feel bad',
#  'access account time today time apps log verification access password otp worst.. bad experience',
#  'helpful online market offline store price great delivery',
#  'today feb 2019 account login why..',
#  'satisfied service',
#  'auto logout cant login turn autologoff update',
#  'good place online coupon sale..',
#  'easy sell buy stuff save online payment',
#  'great..very easy seller reseller friendship..',
#  'best market place experience great',
#  'local commerce best apps',
#  'good buy sell apps',
#  'great great experience',
#  'cash back.. everyday',
#  'efficient reliable',
#  'error.. asap',
#  'bought tumi bag advertised original shipped replica official store verfied it.. filed complain admin not fake not course not replica picture tracing number dumb c..full',
#  'great experience promotion not good cashback imho best online market indonesia',
#  'love best market place indonesia use daily basis offer promotion commerce payment',
#  'nice app.. market place good team apps crashing time',
#  'love completeness buy stuff delivered house easy pay money buy gold super making improvement service',
#  'live android smartphone',
#  'better bukalapak william stay politics religion issue rocking',
#  'change number wait 1x24 hour open account verification',
#  'cool pay installment',
#  'free shipping service moving',
#  'nice app.. know.. portion promotion lower before..',
#  'nice cant innovative reliable online indo',
#  'easy use promotional event good apps',
#  'great market place apps 2016',
#  'best market place indonesia haobang',
#  'love user interface.. easy sort filter item',
#  'great experience shop best market place indonesia',
#  'useful helpful',
#  'great thing super helpful',
#  'best customer care quick response',
#  'good partner seller buyer',
#  'best place buy online',
#  'trusted online store reputation',
#  'love shop product useful',
#  'business..don stupid step',
#  'time easy use good product',
#  'easy use connects market',
#  'place option product buy seller well',
#  'good application.. up..',
#  'good commerce compare',
#  'nice apps prominent reputable sellers..',
#  'helpful feel secure shop',
#  'fall love application.. sukaa banget',
#  'trusted far.. developing good',
#  'love user interface stability',
#  'best online apps easy search',
#  'great apps great selection seller',
#  'easy use ceonya aneh2',
#  'best commerce indonesia',
#  'best commerce apps indonesia',
#  'best commerce indonesia..',
#  'commerce market place terbaik userfriendly',
#  'best market place',
#  'good easy use',
#  'best online indonesia',
#  'sale service admin customer good helpful day unpleasant experience seller problem well managed admin return good get money customer satisfaction guaranteed',
#  'loyal customer born improvement love good job',
#  'apps helpful easy use pay give promo',
#  'useful promos cashback live withour',
#  'best market place easy use customer benefit',
#  'good activity',
#  'complain payment issue unsolve today month',
#  'enjoying improved throw star',
#  'useful apps easily pay',
#  'nice apps bring local competitive',
#  'useful feature',
#  'satisfied service excellent',
#  'good work.. sale maksudnyer',
#  'user friendly improve customer service chat online',
#  'politics',
#  'good service seller buyer',
#  '',
#  'online simple',
#  'best interface best uiux market place',
#  'good satisfied',
#  'best commerce indonesia',
#  'good very.responsif',
#  'online',
#  'much better bukalapak..or bukahoax hmm',
#  'easy understand enjoy commerce',
#  'useful online',
#  'great market place indonesian',
#  'good online shop',
#  'good friendly',
#  'best online indonesia',
#  'transaction failed completed admin cooperative mediate seller buyer finding best solution party time much much better online shop..',
#  'not pay credit card lastest customer support use desktop version',
#  'good bunch stuff friendly user well well',
#  'much bug laggy crash',
#  'great stuff decorate room',
#  'item payment courier good service btw doorprize winner',
#  'helpful easy use user day',
#  'good great vendor',
#  'great loved use daily',
#  'online transaction',
#  'user friendly clear fast',
#  'useful daily use shop stuff',
#  'useful',
#  'best much better bukalapak',
#  'work well',
#  'good apps fast simple.dan accurate',
#  'use seller offline cant buy stuff money refunded cant receive money bank account not connect hour not single picked phone user choice award bet..full',
#  'best online shop easy use superb flash sale',
#  'best market place transaction.. not like app..',
#  'reliable market place currently easy buy track buying',
#  'best market place indonesia',
#  'nice buyer seller',
#  'best online apps easy use',
#  'best market place tokopedia.. bravo',
#  'personally use trust fast responsive reliable',
#  'good hope add paylater service great',
#  'good market place buy stuff trustworthy seller good customer protection service',
#  'good helpful handy use apps',
#  'apps useful helpfull.very great..user friendly',
#  'best online experience indonesia',
#  'good easy use rich feature good work',
#  'help',
#  'good online andalanku',
#  'nice apps.. complete simple use',
#  'easy use user friendly',
#  'easy use.. great',
#  'best buying selling product',
#  'offense but.. easier others.. like much.. tokped.. awesome',
#  'good apps shop.. easy life dont market reason.. thxu',
#  'best commerce',
#  'love buy thing safe online',
#  '',
#  'like',
#  'great online shop apps easy safe use device',
#  'useful favorite ecomm apps site',
#  'helpful online easy use',
#  'good',
#  'best place',
#  'easy use reliable',
#  'dark mode',
#  'user friendly needed great',
#  'good okkey',
#  'lagged phone huawei honor not everytime open loading screen long press search search click product black screen phone freeze frustate much',
#  'good feature more.. simply best market place online',
#  'best bad transaction',
#  'apps not permit buyer cancel order change address delivery bad customer seller not confirmed send item seller not change delivery address too.. bad apps',
#  'not hate love pretty annoying rush use service stalled minute process logging stay logged',
#  'offer reliable service help mobile immobile service like purchasing daily stuff paying utility great help',
#  'good helpful',
#  'good excellent.. like tokopedia..',
#  'good major issue major issue seller',
#  '',
#  'user friendly great interface',
#  'easy use track order',
#  'easy use complete great',
#  'great online',
#  'best experience',
#  'helpful place cashback',
#  'good highly recommended',
#  'problem good',
#  'good platform online easy use process stage',
#  'best market place apps indonesia',
#  'easy simple shopping..',
#  'straightforward easy use',
#  'best good work decacorn hectocorn',
#  'super cashback',
#  'best',
#  'good app.. satisfying',
#  'best online shop',
#  'amazing unicorn online online dah',
#  'great easy use',
#  'great',
#  'recommended safety trading',
#  'nice recommended',
#  'easy use',
#  'excellent online',
#  'flawless times..',
#  'helpful good',
#  'great market place pleasee.. bring minimum credit purchase limit 500.00 high',
#  'like much like change language english',
#  'best online store indonesia user friendly secure transaction rated frequent online shopper indonesia',
#  'heard news leak customer personal data panic erase account update personal shame unistalled',
#  'good market place nice easy use',
#  'unable activate ovo account',
#  'great love',
#  'phone center not bad',
#  'powerful best online good recommended',
#  'excellent online shop indonesia',
#  'best online shop iloveyou',
#  'recommended plenty promotion easy payment especialy ovo',
#  'nice apps like',
#  'best shop indonesia much',
#  'image not load refreshed totally suck',
#  ...]

# %% [markdown]
# listRev

# %%
#cek masih ada stopword gak di listRev
splitdata = []
for idx, i in enumerate(listRev):
    try:
        i = i.split()
        splitdata.append(i)
        for d in i:
            if d in stopwords[0]:
                print("{},{}".format(d,idx))
    except:
        None

# %% [markdown]
# udah gak ada stopword, tapi masih ada simbol ..
# coba tanpa dihapus dulu bisa diinterpretasiin gak nanti

# %%
#coba hapus stopword lang='id'
stops, lemmatizer = LoadStopWords(lang='id')
for i,d in tqdm(enumerate(listRev)):
    try:
        #i=i.translate(to='en')
        #i= nltk.word_tokenize(i)
        listRev[i] = cleanText(d,fix={}, lemma=lemmatizer,lang='id', stops = stops, symbols_remove = True, min_charLen =2)
    except:
        print(i)
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))

# %%
#save to csv file 
data_clean=pd.DataFrame(listRev,columns=['Cleaned_review'])
Clean=pd.concat([data['Date'],data['Rating'],data['Review'],data_clean], axis=1)

# %%
def data_to_csv(filename, data):
    """Export entire DataFrame to csv."""
    output = data
    output.to_csv(filename, index=True)
data_to_csv('C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/tokped_bersih3.csv', Clean)

# %%
Clean
# Out:
#            Date  Rating                                             Review  \
# 0     17-Oct-18       5                                     Recomended app
# 1     12-Nov-18       5  I have relied on Tokopedia to obtain from chea...
# 2     13-Nov-18       2  What's with OVO shovel treatment? Dissapointed...
# 3     13-Nov-18       2  The features failed way too much (like the cha...
# 4     17-Nov-18       5            good app, functioned well minimum crash
# 5     21-Nov-18       5  Fly brethren, keep up the great work. Proudnes...
# 6     22-Nov-18       5  Still favourite one! Even if there's update, t...
# 7     22-Nov-18       5  Most Simple UI Marketplace i've ever used. Gre...
# 8     22-Nov-18       5  Instant delivery is not shown in application ,...
# 9     22-Nov-18       1  Heck this app is so stupid where's my order it...
# 10    22-Nov-18       5        Wonderful app for Indonesia and the world 👍
# 11    23-Nov-18       5  Its a must have app. You can find anything for...
# 12    23-Nov-18       5                 This app all of one the best app!!
# 13    23-Nov-18       2  nice ui you got there makes me want to uninsta...
# 14    23-Nov-18       5  The apps is stable and secure for online trans...
# 15    23-Nov-18       5  Very Good App and Usefull. Many Thanks to Toko...
# 16    23-Nov-18       5     Great app with complete features and products!
# 17    23-Nov-18       5                       Good aplication..easy to use
# 18    24-Nov-18       4  Somwtimes there is still some server error tha...
# 19    24-Nov-18       5   mantaplah. tampilan simple and clean. i like it!
# 20    24-Nov-18       5  Very trusted shopping platform with high secur...
# 21    24-Nov-18       5   Nice and simple app for buying and selling goods
# 22    24-Nov-18       5  Great Trading App! let us connect to achieve S...
# 23    24-Nov-18       5                        Good app. Highly recommend.
# 24    24-Nov-18       5  Really helpful online store app with so many p...
# 25    24-Nov-18       5  Nice onelide shop app!! And simple payment met...
# 26    24-Nov-18       5                 Very good. Help me more everything
# 27    24-Nov-18       4  I hope Tokopedia can pay order with Tcash by T...
# 28    24-Nov-18       5                            I love this app, a lot!
# 29    25-Nov-18       4  Improvement in seaching features, which shoukd...
# ...         ...     ...                                                ...
# 3047   9-May-19       5  Satisfying in Service & fast respons also prod...
# 3048   9-May-19       5  very happy with all the features and it's simp...
# 3049   9-May-19       5        Great app, easy to use and many promotion..
# 3050   9-May-19       5                Awesome application. Very reliable.
# 3051   9-May-19       5                         Awesome....... thank you !
# 3052   9-May-19       5             nice marketplace go go go go Tokopedia
# 3053   9-May-19       5                       good aplication, easy to use
# 3054   9-May-19       5                         such a good app to install
# 3055   9-May-19       4        good but have to improve the seller quality
# 3056   9-May-19       5                                The Best OL SHOP!!!
# 3057   9-May-19       5                          my favorite olshop so far
# 3058   9-May-19       1                      stop advertise so much freako
# 3059   9-May-19       5                      Very good and easy to use it.
# 3060   9-May-19       5                                  Good for business
# 3061   9-May-19       5                                   nice and smooth.
# 3062   9-May-19       5                         Very helpfull applications
# 3063   9-May-19       1                            must update when to pay
# 3064   9-May-19       2                              need more improvement
# 3065   9-May-19       5                               nice shopping at all
# 3066   9-May-19       5                        good apk for online shoping
# 3067   9-May-19       5                                     nice app good!
# 3068   9-May-19       5                                   nice to shop app
# 3069   9-May-19       5                                Easy,, simple, aman
# 3070   9-May-19       5                                      very use full
# 3071   9-May-19       4                                  very good service
# 3072   9-May-19       5                               good.. good.. good..
# 3073   9-May-19       4                               Good Jobless itp lol
# 3074   9-May-19       5                                       best to best
# 3075   9-May-19       5              I LIKE THIS SO GOOD MAKE ME RICH AMIN
# 3076  10-May-19       4  kmrn bsa buat bayar cc BNI skrg kok gk bsa lag...
#
#                                          Cleaned_review
# 0                                           recommended
# 1     relied cheap mundane item pricy gadget extra c...
# 2     ovo shovel treatment dissapointed narrow money...
# 3     feature failed much like chat feature crashed ...
# 4                    good functioned well minimum crash
# 5                fly brother great work proudness heart
# 6            favourite update waiting long enjoy online
# 7                  simple market place great job workin
# 8     instant delivery not adjustment easier understand
# 9                 stupid order like month order package
# 10                                  wonderful indonesia
# 11                                                 good
# 12                                                 best
# 13                   nice uninstall change tokocash ovo
# 14                apps stable secure online transaction
# 15                                          good useful
# 16                       great complete feature product
# 17                          good aplication .. easy use
# 18                           server error annoying good
# 19                 mantaplah tampilan simple clean like
# 20    trusted platform high security transaction buy...
# 21                      nice simple buying selling good
# 22                    great trading connect achieve big
# 23                                good highly recommend
# 24                          helpful online store promos
# 25               nice online shop simple payment method
# 26                                            good help
# 27                       hope pay order tcash telk msel
# 28                                                 love
# 29    improvement seaching feature include word sear...
# ...                                                 ...
# 3047  satisfying service fast respons product suitab...
# 3048                           happy feature simple use
# 3049                        great easy use promotion ..
# 3050                                   awesome reliable
# 3051                                         awesome ..
# 3052                                  nice market place
# 3053                                      good easy use
# 3054                                       good install
# 3055                        good improve seller quality
# 3056                                   best online shop
# 3057                                    favorite olshop
# 3058                          stop advertise much freak
# 3059                                      good easy use
# 3060                                               good
# 3061                                        nice smooth
# 3062                                            helpful
# 3063                                         update pay
# 3064                                        improvement
# 3065                                               nice
# 3066                                        good online
# 3067                                          nice good
# 3068                                          nice shop
# 3069                                   easy simple aman
# 3070                                                use
# 3071                                       good service
# 3072                            good .. good .. good ..
# 3073                               good jobless itp lol
# 3074                                          best best
# 3075                                like good rich amin
# 3076                        kmrn bsa bayar bni skrg bsa
#
# [3077 rows x 4 columns]

# %%
#cek data nan
text = pd.read_csv('C:/WinPython_64bit/notebooks/Google-Play-Store-Review-Extractor-master/tokped_bersih3.csv')
nan=text['Cleaned_review']
splitting = []

for idx, i in enumerate(nan):
    try:
        i = i.split()
        splitting.append(i)
    except:
        print("{},{}".format(i,idx))
# Out:
# nan,75
# nan,883
# nan,938
# nan,958
# nan,1040
# nan,1076
# nan,1163
# nan,1225
# nan,1348
# nan,1397
# nan,1578
# nan,1593
# nan,1769
# nan,1841
# nan,1859
# nan,1993
# nan,2004
# nan,2055
# nan,2067
# nan,2091
# nan,2154
# nan,2193
# nan,2199
# nan,2231
# nan,2277
# nan,2364
# nan,2437
# nan,2530
# nan,2789
# nan,2871
# nan,2873
# nan,2982

# %%
nan.isna().sum() #hitung jumlah nan/data kosong
# Out:
# 32

# %%
# coba lihat VSM nya
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

df = pd.read_csv('tokped_bersih3.csv')
cleanreview = df['Cleaned_review']

listdf=cleanreview.values.astype('U')
listdf = [d for d in listdf]

Tfidf_vectorizer = TfidfVectorizer(max_df=0.75, min_df=5)
tfidf = Tfidf_vectorizer.fit_transform(listdf)
tfidf_term = Tfidf_vectorizer.get_feature_names()
print(tfidf.shape)
# Out:
# (3077, 325)

# %%
print(tfidf)
# Out:
#   (0, 237)	1.0
#   (1, 40)	0.3278717567461708
#   (1, 151)	0.2686588594347588
#   (1, 34)	0.3753775377636099
#   (1, 261)	0.3245257086571764
#   (1, 74)	0.36046244470293454
#   (1, 248)	0.2919350207004126
#   (1, 43)	0.29935419139037467
#   (1, 277)	0.2586576240172321
#   (1, 65)	0.3488933997312536
#   (1, 312)	0.19846701856963056
#   (1, 113)	0.20323780746883618
#   (2, 151)	0.2567704039599487
#   (2, 201)	0.2806964423753798
#   (2, 177)	0.2806964423753798
#   (2, 127)	0.29910798075131645
#   (2, 308)	0.30537537981461055
#   (2, 216)	0.3043287542738001
#   (2, 213)	0.29910798075131645
#   (2, 36)	0.2567704039599487
#   (2, 301)	0.351128260992732
#   (2, 206)	0.24808877533178522
#   (2, 227)	0.29910798075131645
#   (2, 114)	0.26730314614786016
#   (3, 114)	0.19394886524032037
#   :	:
#   (3059, 87)	0.5871416965134022
#   (3060, 122)	1.0
#   (3061, 184)	0.4870642322615265
#   (3061, 268)	0.8733661509650404
#   (3062, 131)	1.0
#   (3063, 305)	0.657517860496867
#   (3063, 204)	0.7534389577979246
#   (3064, 140)	1.0
#   (3065, 184)	1.0
#   (3066, 122)	0.6031689763770854
#   (3066, 194)	0.79761343139156
#   (3067, 122)	0.5162188952022756
#   (3067, 184)	0.8564566843899005
#   (3068, 184)	0.7267494443511859
#   (3068, 262)	0.6869026460389
#   (3069, 264)	0.8511868506867883
#   (3069, 87)	0.5248627870385812
#   (3070, 308)	1.0
#   (3071, 122)	0.46387290776747653
#   (3071, 260)	0.8859017583453294
#   (3072, 122)	1.0
#   (3073, 122)	1.0
#   (3074, 19)	1.0
#   (3075, 159)	0.891947211337221
#   (3075, 122)	0.4521395494620603

# %%
# coba lihat VSM nya

from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer

df = pd.read_csv('tokped_bersih3.csv')
cleanreview = df['Cleaned_review']

listdf=cleanreview.values.astype('U')
listdf = [d for d in listdf]

Tfidf_vectorizer = TfidfVectorizer(max_df=1.0, min_df=1) #nilai default max_df dan min_df
tfidf = Tfidf_vectorizer.fit_transform(listdf)
tfidf_term = Tfidf_vectorizer.get_feature_names()
print(tfidf.shape)
# Out:
# (3077, 2097)

# %% [markdown]
# max_df = 0.5 means "ignore terms that appear in more than 50% of the documents".
#
# max_df = 25 means "ignore terms that appear in more than 25 documents".
#
# The default max_df is 1.0, which means "ignore terms that appear in more than 100% of the documents". Thus, the default setting does not ignore any terms.
#
#
# min_df = 0.01 means "ignore terms that appear in less than 1% of the documents".
#
# min_df = 5 means "ignore terms that appear in less than 5 documents".
#
# The default min_df is 1, which means "ignore terms that appear in less than 1 document". Thus, the default setting does not ignore any terms.

# %%
print(tfidf)
# Out:
#   (0, 1479)	1.0
#   (1, 1504)	0.27082555401379893
#   (1, 317)	0.20538670676412082
#   (1, 1186)	0.27082555401379893
#   (1, 965)	0.16829433230208962
#   (1, 1382)	0.27082555401379893
#   (1, 756)	0.27082555401379893
#   (1, 656)	0.24106679707706485
#   (1, 287)	0.23514546370085493
#   (1, 821)	0.24831392342524583
#   (1, 1662)	0.2032906622481396
#   (1, 486)	0.22580229283669273
#   (1, 646)	0.25765709428940803
#   (1, 1598)	0.18287507617556772
#   (1, 329)	0.18752262206379705
#   (1, 1780)	0.16202931933981507
#   (1, 431)	0.21855516648851175
#   (1, 1992)	0.12432448512747997
#   (1, 742)	0.12731302134785727
#   (1, 494)	0.24831392342524583
#   (1, 389)	0.25765709428940803
#   (2, 965)	0.15684235033934846
#   (2, 1284)	0.17145702571280422
#   (2, 1673)	0.2523965949562342
#   (2, 1924)	0.2523965949562342
#   :	:
#   (3067, 782)	0.5162188952022756
#   (3067, 1211)	0.8564566843899005
#   (3068, 1211)	0.7267494443511859
#   (3068, 1664)	0.6869026460389
#   (3069, 1687)	0.45729068391371397
#   (3069, 574)	0.2819767042360588
#   (3069, 86)	0.8434301208007087
#   (3070, 1988)	1.0
#   (3071, 782)	0.46387290776747653
#   (3071, 1646)	0.8859017583453294
#   (3072, 782)	1.0
#   (3073, 782)	0.15957103436302358
#   (3073, 1062)	0.551023097265745
#   (3073, 976)	0.5791850443821818
#   (3073, 966)	0.5791850443821818
#   (3074, 198)	1.0
#   (3075, 1041)	0.36543822811390925
#   (3075, 782)	0.18524535276916507
#   (3075, 1565)	0.6164843160977311
#   (3075, 90)	0.6723735187497397
#   (3076, 998)	0.35355339059327373
#   (3076, 252)	0.7071067811865475
#   (3076, 186)	0.35355339059327373
#   (3076, 218)	0.35355339059327373
#   (3076, 1697)	0.35355339059327373

# %%
#baris kosong di vsm
baris_kosong = []
nBaris, nKolom = tfidf.shape
for i in range(nBaris):
    if sum(tfidf[i].data)==0:
        baris_kosong.append(i)
print('Jumlah baris kosong di VSM tfidf = ', len(baris_kosong))
print(baris_kosong)
# Out:
# Jumlah baris kosong di VSM tfidf =  0
# []

# %%
#ignore nan data

tfidf_nonZeroRows = tfidf[tfidf.getnnz(1)>0] # Remove Zero Rows
tfidf_nonZeroCols = tfidf[:,tfidf.getnnz(0)>0] # Remove Zero Columns. Becareful, it "might" change the VSM interpretation (word index)
tfidf_nonZeroRC = tfidf[tfidf.getnnz(1)>0][:,tfidf.getnnz(0)>0] # Remove Zero Rows and Columns
print(tfidf_nonZeroRows.shape, tfidf_nonZeroCols.shape, tfidf_nonZeroRC.shape)
# Jika jumlah kolom tidak berubah, maka interpretasi (index kata) VSM tidak berubah (aman :) ).
# Out:
# (3077, 2097) (3077, 2097) (3077, 2097)

# %%
tfidf[0]
# Out:
# <1x2097 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1 stored elements in Compressed Sparse Row format>

# %%
print(tfidf[0])
# Out:
#   (0, 1479)	1.0

# %% [markdown]
# ## ini pake tf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
tf_vectorizer = CountVectorizer(binary = False, lowercase=True, stop_words='english')
tf = tf_vectorizer.fit_transform(listdf)
print(tf.shape)
# Out:
# (3077, 2029)

# %%
print(tf)
# Out:
#   (0, 1432)	1
#   (1, 374)	1
#   (1, 477)	1
#   (1, 721)	1
#   (1, 1932)	1
#   (1, 415)	1
#   (1, 1730)	1
#   (1, 315)	1
#   (1, 1551)	1
#   (1, 625)	1
#   (1, 470)	1
#   (1, 1615)	1
#   (1, 797)	1
#   (1, 273)	1
#   (1, 635)	1
#   (1, 734)	1
#   (1, 1336)	1
#   (1, 938)	1
#   (1, 1151)	1
#   (1, 303)	1
#   (1, 1457)	1
#   (2, 1385)	1
#   (2, 1260)	1
#   (2, 1214)	1
#   (2, 269)	1
#   :	:
#   (3067, 1175)	1
#   (3067, 758)	1
#   (3068, 1617)	1
#   (3068, 1175)	1
#   (3069, 82)	1
#   (3069, 557)	1
#   (3069, 1640)	1
#   (3070, 1928)	1
#   (3071, 1599)	1
#   (3071, 758)	1
#   (3072, 758)	3
#   (3073, 939)	1
#   (3073, 948)	1
#   (3073, 1033)	1
#   (3073, 758)	1
#   (3074, 187)	2
#   (3075, 86)	1
#   (3075, 1518)	1
#   (3075, 758)	1
#   (3075, 1012)	1
#   (3076, 1650)	1
#   (3076, 207)	1
#   (3076, 177)	1
#   (3076, 241)	2
#   (3076, 969)	1
